# %%
import numpy as np
import matplotlib.pyplot as plt


fig, ax = plt.subplots(1, 1, figsize=(10, 6))

datapath = r'C:\Users\sevke\Desktop\Dev\MA\phonokit\plot\3y_1y2x_3y\kappa\3y_1y2x_3y___PT_elL=Ribbon2D_elR=Ribbon2D_CC=FiniteLattice2D_intrange=1_kc=900_kc_xy=180_KAPPA.dat'

data = np.loadtxt(datapath, skiprows=1)

temp = data[:, 0]
kappa = data[:, 1]

# plot kappa
ax.plot(temp, kappa, label=r"$\kappa$ (pW/K)", color="tab:red")
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("Thermal Conductance (pW/K)")
ax.legend()
plt.show()
